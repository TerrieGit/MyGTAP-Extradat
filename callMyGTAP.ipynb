# %%
# The requirements to run this program are listed in requirements.txt. Before running this file you should:
# 1. create a virtual environment 
# 2. install the required programs from the requirements.txt file: py -m pip install -r requirements.txt.

# %%
# Main programs are located in DataFunctions.py, which must be imported
import DataFunctions as DF

# %%
# Year and version for which we need data - if version is not listed then you would need to add two sheets to GTAPMap.xlsx with the apropriate sets and mappings.
year = int(input("Please enter the year (options 2004, 2007, 2011, 2014, 2017, 2019, 2023): "))
version = input("Please enter the GTAP version for appropriate mapping to GTAP regions (options v9a, v10a, v11c, v12): ")
# Out:
# Please enter the year (options 2004, 2007, 2011, 2014, 2017, 2019, 2023):  2023
# Please enter the GTAP version for appropriate mapping to GTAP regions (options v9a, v10a, v11c, v12):  v12

# %%
DF.MyGTAPConstruct(year,version)
# Out:
# <class 'pandas.DataFrame'>
# Index: 265 entries, ABW to ZWE
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2023    265 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1+ KB
# <class 'pandas.DataFrame'>
# Index: 262 entries, ABW to ZWE
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2023    262 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1+ KB
# <class 'pandas.DataFrame'>
# Index: 296 entries, USA to KWT
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2023    182 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6+ KB
# <class 'pandas.DataFrame'>
# Index: 297 entries, DNK to KWT
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2023    184 non-null    float64
# dtypes: float64(1)
# ...

# %%
# For those wanting to run multiple years and versions you can also use the following syntax:
# DF.MyGTAPConstruct(2023,'v12')
# DF.MyGTAPConstruct(2019,'v12')
# DF.MyGTAPConstruct(2017,'v11')
